# %% [markdown]
# <h2><font color='RED'>Database: Final Project</font></h2>
# <h1><font color='Darkred'>Shipping Optimization & Customer Satisfication Project</font></h1>
# <p><font color='blue'>Team Members:</font></p>
# <p><font color='blue'>DB architect: Asyama Baibarakova</font></p>
# <p><font color='blue'>DB analyst: Muratova Jamilya</font></p>
# <p><font color='blue'>SQL developer: Sabyrova Jarkynai</font></p>
# <p><font color='blue'>AI engineer: Abibilaev Aknazar</font></p>

# %% [markdown]
# <h2>Dataset: E-Commerce Shipping Data</h2>

# %%
from IPython.display import Image
image_url = 'https://github.com/aki0923/files/blob/main/dataset.png?raw=true'
Image(url=image_url)
# Out:
# <img src="https://github.com/aki0923/files/blob/main/dataset.png?raw=true"/>

# %% [markdown]
# <h2>1. Introduction and Overview of the Problem</h2>

# %% [markdown]
# <h3>What is the business about? </h3>
#   <h3>  The online store is facing a number of operational problems that negatively affect the quality of customer service.:</h3>
#
# <font color='red'>Delays in the delivery of orders.</font>
#
# <font color='red'>Unstable quality of couriers' work.</font>
#
# <font color='red'>Customer dissatisfaction (low level of Customer Satisfaction).</font>
#
# <font color='red'>The goal of the business is to improve the delivery process and service to increase loyalty and operational efficiency.</font>

# %% [markdown]
# <h3>Content</h3>
#
# <h4>The dataset used for model building contained 10999 observations of 12 variables.</h4>

# %% [markdown]
# <h4>List of Columns and Their Descriptions</h4>

# %%
from IPython.display import Image
image_url = 'https://github.com/aki0923/files/blob/main/list%20of%20columns.png?raw=true'
Image(url=image_url)
# Out:
# <img src="https://github.com/aki0923/files/blob/main/list%20of%20columns.png?raw=true"/>

# %% [markdown]
# 1. Dataset analysis

# %% [markdown]
# Это одна “плоская” таблица. Чтобы нормализовать до 3NF и получить 5 таблиц, нужно:
#
# выделить сущности (Customers, Products, Shipments)
#
# вынести справочники (Warehouse_block, Modes, Product_importance)

# %% [markdown]
# 2. Предлагаемая ER-схема

# %%
1. Customers

# %%
Field	Type
customer_id (PK)	INT
gender	ENUM('M','F')
prior_purchases	INT
customer_care_calls	INT
customer_rating	INT

# %%
2. Products

# %%
Field	Type
product_id (PK)	INT
cost	INT
importance_id (FK)	INT
weight_gms	INT
discount_offered	INT

# %%
3. Product_Importance

# %%
Field	Type
importance_id (PK)	INT
importance_name	VARCHAR

# %%
4. Shipments

# %%
Field	Type
shipment_id (PK)	INT
customer_id (FK)	INT
product_id (FK)	INT
warehouse_id (FK)	INT
mode_id (FK)	INT
reached_on_time	TINYINT
# Out:
#   Cell In[1], line 1
#     Field	Type
#          	^
# SyntaxError: invalid syntax

# %%
5. Warehouse

# %%
Field	Type
warehouse_id (PK)	INT
warehouse_block	CHAR(1)

# %%
6. Shipment_Mode

# %%
Field	Type
mode_id (PK)	INT
mode_name	VARCHAR

# %%
УК диагарма

# %%
from IPython.display import Image
image_url = 'https://github.com/aki0923/files/blob/main/eer%20diagram.png?raw=true'
Image(url=image_url)
# Out:
# <img src="https://github.com/aki0923/files/blob/main/eer%20diagram.png?raw=true"/>
